# %% [markdown]
# <a href="https://colab.research.google.com/github/mrbharat007/Bootcamp-ML/blob/main/b2_gla_session2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello GLA Batch 2")
# Out:
# Hello GLA Batch 2

# %%
print("I am all set for session2 ")
# Out:
# I am all set for session2
