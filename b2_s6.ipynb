# %% [markdown]
# <a href="https://colab.research.google.com/github/mrbharat007/Bootcamp-ML/blob/main/b2_s6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Machine learning improves by measuring error and correcting itself step by step

# %%
#feature
#label
#prediction problem
#conclusion from the visible data

# %%
#classification- it mean are classifying an object
#regression- to predict a continous problem

# %%
#Face unlock
#predicting land prices
#google photos use what to define faces
#weather forecast


#classification-

#Student results--
JEE MAINS (marks to rank)


XYZ marks---2 digit

#feature
percentile
score
rank
category
study hours per day
no of questions attempted
shifts
no students attempted
difficulty level of shift



percentile -raw marks

# %%
#color different
#position
