# %% [markdown]
# <a href="https://colab.research.google.com/github/mrbharat007/Bootcamp-ML/blob/main/b2_session3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
No memorizing syntaxes
# Out:
#   File "/tmp/ipykernel_377/2219988234.py", line 1
#     No memorizing syntaxes
#        ^
# SyntaxError: invalid syntax

# %%
focussing on the logic

# %%
#Variable

student_name ="Riya"
student_age=20

print(student_name)
print(student_age)
#assignment operator
# Out:
# Riya
# 20

# %%
student name ="riya"
student_name ="riya"

# %%
#String- TEXT
#Integer is whole number
#float is decimal values
#Boolean values 0 or 1
complex

#small snippet that has all these 4 data types
student_name ="Riya"
student_age=20
attendance=85.5
is_present= True

# %%
we cannot do proper math for strings untill and unless we convert them into numbers (LLM)

# %%
mark1= 78
mark2 =85

marks= [78,85,62]

#create a list of 5 subjects  and print the 1st and last element of that list

# %%
#Dictionary --KEY and VALUE

student =["Ayush",19,"AIML",88]


#extraction

student ={
    "name":"Ayush",
    "age":19,
    "course":"AIML"
    "attendance":88
}

# %%
each row in a dataset can imagined as a dictionary

# %%
conditions

<>=

#write a code for pass or fail, pass be 40 or above
#run this code on a list of student of 5 students

# %%
#code to check whether a number is positive negative or zero: Given list of number

# %%
variables, lists, dictionaies conditions and loops

@student Dictionary of 5 students
#name, study_hours, attendance and marks

#student name as input
based on their marks you have to consider a print statement for "performance"
marks is more than 75 then performance is strong
marks is equal to or greater than 40, performance should print needs improvement
less 20 then print fail repeat class


atendance 75- warning low attendance

study_hours less than 4
print should come warning needs more study time
# Out:
#   File "/tmp/ipykernel_377/62006447.py", line 1
#     variables, lists, dictionaies conditions and loops
#                                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# In payment processing systems, certain transactions are flagged for review based on specific patterns.
#
# Write a script that loops through a list of transaction dictionaries. If a transaction amount is greater than 5000 AND the payment method is "Gift Card", append the transaction_id to a new list called flagged_transactions. Once the loop completes, print the flagged_transactions list.

# %%
# Student Starter Code
transactions = [
    {"transaction_id": "TX101", "amount": 6200, "method": "Credit Card"},
    {"transaction_id": "TX102", "amount": 5500, "method": "Gift Card"},
    {"transaction_id": "TX103", "amount": 1200, "method": "Gift Card"},
    {"transaction_id": "TX104", "amount": 8000, "method": "Gift Card"},
    {"transaction_id": "TX105", "amount": 450, "method": "PayPal"}
]

flagged_transactions = []

# Write your code below to find anomalous patterns

#for and in loop

for tx in transactions:
  if tx["amount"]>5000 and tx["method"]=="Gift Card":
    flagged_transactions.append(tx["transaction_id"])

print("Flagged Transactions:",flagged_transactions)
# Out:
# Flagged Transactions: ['TX102', 'TX104']
